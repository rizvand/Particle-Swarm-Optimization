# %% [markdown]
# # SIMULATION

# %%
import pickle
import time
from PSO import *
from testfunction import *
import matplotlib.pyplot as plt
import seaborn as sns
def save_object(obj, filename):
    with open(filename, 'wb') as output:  # Overwrites any existing file.
        pickle.dump(obj, output, pickle.HIGHEST_PROTOCOL)
        
def load_object(filename):
    with open(filename, 'rb') as input:
        return pickle.load(input)

# %%
size_list = [10,100,1000]
n_iter_list = [10,100,1000]
dim_list = [2,3,4,5]
time_list = []
name_list = []
for size in size_list:
    for n_iter in n_iter_list:
        for dim in dim_list:
            pso = PSO(size=size, 
                      n_iter=n_iter, 
                      fitness_function=sphere, 
                      position_boundary=[(-1.0, 1.0)]*dim,
                      velocity_boundary=[(-0.3, 0.3)]*dim,
                      w_inertia = 0.5,
                      C1 = 1,
                      C2 = 2,
                      random_state = 42,
                      print_best = False,
                      save_history = True)
            start = time.time()
            pso.simulate()
            end = time.time()
            time_list.append(end-start)
            name_list.append('PSO_dim_{}_size_{}_n_iter_{}'.format(dim, size, n_iter))
            save_object(pso, 'result/PSO_dim_{}_size_{}_n_iter_{}.pkl'.format(dim, size, n_iter))
save_object(name_list, 'result/PSO_simulation_id.pkl')
save_object(time_list, 'result/PSO_simulation_time.pkl')

# %% [markdown]
# # Get Result

# %%
import pandas as pd
name_report = load_object('result/PSO_simulation_id.pkl')
time_report = load_object('result/PSO_simulation_time.pkl')
list_of_object = [load_object('result/'+x+'.pkl') for x in name_report]

# %%
size = []
n_iter = []
dim = []
best_solution = []
best_fitness = []
for x in list_of_object:
    sol, fit  = x.best_history[-1]
    best_solution.append(sol)
    best_fitness.append(fit)
    size.append(x.size)
    n_iter.append(x.n_iter)
    dim.append(len(sol))
best_solution = [x.tolist() for x in  best_solution]

# %%
df_report = pd.DataFrame({'id': name_report, 'dimension': dim, 'population_size': size, 'n_iter': n_iter, 'time': time_report, 'solution': best_solution, 'fitness': best_fitness})
df_report['convergence'] = df_report['fitness'].apply(lambda x: True if x < 1e-4 else False)
df_report = df_report.sort_values(by=['dimension','n_iter', 'population_size'])

# %%
df_report
# Out:
#                                  id  dimension  population_size  n_iter  \
# 0       PSO_dim_2_size_10_n_iter_10          2               10      10
# 12     PSO_dim_2_size_100_n_iter_10          2              100      10
# 24    PSO_dim_2_size_1000_n_iter_10          2             1000      10
# 4      PSO_dim_2_size_10_n_iter_100          2               10     100
# 16    PSO_dim_2_size_100_n_iter_100          2              100     100
# 28   PSO_dim_2_size_1000_n_iter_100          2             1000     100
# 8     PSO_dim_2_size_10_n_iter_1000          2               10    1000
# 20   PSO_dim_2_size_100_n_iter_1000          2              100    1000
# 32  PSO_dim_2_size_1000_n_iter_1000          2             1000    1000
# 1       PSO_dim_3_size_10_n_iter_10          3               10      10
# 13     PSO_dim_3_size_100_n_iter_10          3              100      10
# 25    PSO_dim_3_size_1000_n_iter_10          3             1000      10
# 5      PSO_dim_3_size_10_n_iter_100          3               10     100
# 17    PSO_dim_3_size_100_n_iter_100          3              100     100
# 29   PSO_dim_3_size_1000_n_iter_100          3             1000     100
# 9     PSO_dim_3_size_10_n_iter_1000          3               10    1000
# 21   PSO_dim_3_size_100_n_iter_1000          3              100    1000
# 33  PSO_dim_3_size_1000_n_iter_1000          3             1000    1000
# 2       PSO_dim_4_size_10_n_iter_10          4               10      10
# 14     PSO_dim_4_size_100_n_iter_10          4              100      10
# 26    PSO_dim_4_size_1000_n_iter_10          4             1000      10
# 6      PSO_dim_4_size_10_n_iter_100          4               10     100
# 18    PSO_dim_4_size_100_n_iter_100          4              100     100
# 30   PSO_dim_4_size_1000_n_iter_100          4             1000     100
# 10    PSO_dim_4_size_10_n_iter_1000          4               10    1000
# 22   PSO_dim_4_size_100_n_iter_1000          4              100    1000
# 34  PSO_dim_4_size_1000_n_iter_1000          4             1000    1000
# 3       PSO_dim_5_size_10_n_iter_10          5               10      10
# 15     PSO_dim_5_size_100_n_iter_10          5              100      10
# 27    PSO_dim_5_size_1000_n_iter_10          5             1000      10
# 7      PSO_dim_5_size_10_n_iter_100          5               10     100
# 19    PSO_dim_5_size_100_n_iter_100          5              100     100
# 31   PSO_dim_5_size_1000_n_iter_100          5             1000     100
# 11    PSO_dim_5_size_10_n_iter_1000          5               10    1000
# 23   PSO_dim_5_size_100_n_iter_1000          5              100    1000
# 35  PSO_dim_5_size_1000_n_iter_1000          5             1000    1000
#
#          time                                           solution  \
# 0    0.003031      [0.005533896588799575, -0.014049825836363466]
# 12   0.025001     [0.0029269264391766706, -0.004610687744073076]
# 24   0.259957    [-0.000611930698794283, -9.527674375589719e-05]
# 4    0.025038   [-7.876047208304219e-12, -2.160073368643799e-12]
# 16   0.243950  [-2.1507244074869102e-14, 3.3988092883208043e-14]
# 28   2.600622    [7.749163304409885e-15, -6.978782746356907e-15]
# 8    0.238536   [1.227741365473875e-100, 4.575823049885613e-100]
# 20   3.446365  [1.8536221514311443e-109, 5.1901263499138547e-...
# 32  36.105966  [3.633393758644851e-114, 2.9195816109112603e-115]
# 1    0.002995  [-0.0625414567208877, 0.02539387770376096, -0....
# 13   0.026030  [0.010927251401097217, -0.0008336582841361601,...
# 25   0.274001  [-0.0018418392646077364, 0.001138566966207108,...
# 5    0.026009  [-6.948114836682821e-10, 2.5784479231208815e-1...
# 17   0.247067  [-2.981517298040166e-12, -1.115399548719213e-1...
# 29   2.676955  [1.453500776937246e-14, 1.0149167050209587e-13...
# 9    0.246983  [-7.236710631153504e-88, -1.0390247932429793e-...
# 21   2.821023  [6.718329191093161e-102, 4.7006633645822415e-1...
# 33  35.693937  [1.452730055343482e-108, -1.1636863059095732e-...
# 2    0.003042  [-0.02534490405906087, -0.016159139246594484, ...
# 14   0.027068  [-0.00871322213567785, -0.012519988108058277, ...
# 26   0.284034  [0.0023169923191885683, -0.003594419611836607,...
# 6    0.026003  [-3.7072133636314963e-09, 4.925981949889354e-0...
# 18   0.256002  [3.3592942821543625e-11, 6.87664077344702e-11,...
# 30   3.063991  [-1.3650648412901188e-12, 9.519857414684541e-1...
# 10   0.259978  [2.204286688801465e-75, 1.1905069589285054e-75...
# 22   2.634004  [4.451222135399982e-95, 3.681029831935041e-96,...
# 34  38.978013  [-5.276226656664865e-105, 9.689056842269107e-1...
# 3    0.003000  [-0.007032251470491553, -0.09603091658914265, ...
# 15   0.029058  [-0.012763048005188129, -0.028447907644752163,...
# 27   0.309040  [0.00993352084200505, 0.0030012065516949443, -...
# 7    0.027034  [3.137734658606354e-08, -1.2743592166352216e-0...
# 19   0.348062  [2.404934317091697e-11, 2.3178094743068904e-10...
# 31   2.959998  [9.32119882695675e-13, -6.8369267195632486e-12...
# 11   0.285008  [-5.524602365753052e-67, 3.2950465502450377e-6...
# 23   3.725039  [1.3379666870401063e-88, 2.8093743743822042e-8...
# 35  38.861936  [2.884599101511406e-99, 1.2779762590481294e-98...
#
#           fitness  convergence
# 0    2.280216e-04        False
# 12   2.982534e-05         True
# 24   3.835368e-07         True
# 4    6.669804e-23         True
# 16   1.617752e-27         True
# 28   1.087529e-28         True
# 8   2.244551e-199         True
# 20  3.705289e-218         True
# 32  1.328679e-227         True
# 1    4.786284e-03        False
# 13   1.222931e-04        False
# 25   5.017084e-06         True
# 5    2.132112e-18         True
# 17   1.018881e-23         True
# 29   1.154451e-26         True
# 9   2.779271e-173         True
# 21  2.007020e-202         True
# 33  5.213603e-216         True
# 2    5.677046e-03        False
# 14   3.506178e-04        False
# 26   2.611438e-04        False
# 6    6.754210e-17         True
# 18   1.113811e-20         True
# 30   2.639497e-24         True
# 10  1.390859e-148         True
# 22  1.286290e-188         True
# 34  2.960831e-206         True
# 3    3.204533e-02        False
# 15   3.119974e-03        False
# 27   2.297306e-04        False
# 7    1.382373e-13         True
# 19   5.812287e-19         True
# 31   4.698158e-22         True
# 11  3.105022e-131         True
# 23  2.066377e-175         True
# 35  2.953568e-195         True

# %% [markdown]
# # Plot Time

# %%
def plot(df_report, dimensi, ylim):
    dimensi_2 = df_report[df_report['dimension'] == dimensi]
    plt.plot(dimensi_2['population_size'][:3], dimensi_2['time'][:3], '-o', label='n-iter = 10')
    plt.plot(dimensi_2['population_size'][3:6], dimensi_2['time'][3:6], '-o', label='n-iter = 100')
    plt.plot(dimensi_2['population_size'][6:9], dimensi_2['time'][6:9], '-o', label='n-iter = 1000')
    plt.ylim(0,ylim)
    plt.xlabel('ukuran populasi')
    plt.ylabel('waktu (detik)')
    plt.title(f'PSO - {dimensi} dimensi')
    plt.legend()
    plt.grid()
    plt.savefig(f'foto/PSO_plot_waktu_{dimensi}d.png')
    plt.clf()

# %%
plot(df_report, 2, 900)
plot(df_report, 3, 1100)
plot(df_report, 4, 1300)
plot(df_report, 5, 1400)

# %% [markdown]
# # Plot Time Heatmap

# %%
def plot_heatmap(df_report, dimensi):
    df = df_report[df_report['dimension'] == dimensi]
    matrix = 9999*np.ones((3,3)).flatten().reshape(-1,1)
    time = df['time'].to_numpy().reshape(-1,1)
    for i in range(len(time)):
        matrix[i] = time[i]
    matrix = matrix.reshape(-3,3)
    matrix = np.flip(matrix, axis=0)
    sns.heatmap(matrix, xticklabels=[10,100,100], yticklabels=[1000, 100, 10], cmap='Reds', annot=True, fmt = '.4f', square = True, vmin=0, vmax=150)
    plt.ylabel('n-iter')
    plt.xlabel('pop size')
    plt.title(f'Heatmap Computation Time (Second) PSO - {dimensi} dimension')
    plt.savefig(f'foto/PSO_heatmap_{dimensi}d.png')
    plt.clf()

# %%
plot_heatmap(df_report, 2)
plot_heatmap(df_report, 3)
plot_heatmap(df_report, 4)
plot_heatmap(df_report, 5)

# %% [markdown]
# # Plot Fitness

# %%
df_report['object'] = df_report['id'].apply(lambda x: load_object('result/'+x+'.pkl'))

# %%
def plot_best_fitness(df_report, dimensi, n_iter):
    df_sliced = df_report[(df_report['dimension']==dimensi) & (df_report['n_iter']==n_iter)].reset_index(drop=True)
    for i in range(df_sliced.shape[0]):
        s = df_sliced['population_size'][i]
        plt.plot([x[1] for x in df_sliced['object'][i].best_history], 'o-', ms = 3.5, label=f'pop size = {s}')
    plt.legend()
    plt.grid()
    plt.ylim(0, 0.15*dimensi**1.25)
    plt.ylabel('nilai fitness')
    plt.xlabel('iterasi ke-')
    plt.title(f'Plot Nilai Fitness - PSO {dimensi} dimensi')
    plt.savefig(f'foto/PSO_plot_fitness_{dimensi}d_{n_iter}_iter.png')
    plt.clf()
#     plt.show()

# %%
for dim in [2,3,4,5]:
    for n_iter in [10,100,1000]:
        plot_best_fitness(df_report, dimensi = dim, n_iter = n_iter)

# %% [markdown]
# # Export Report to CSV

# %%
df_report.to_excel('PSO_report.xlsx', index = False)
